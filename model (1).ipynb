# %%
# !pip install --upgrade ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.204-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.7.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: polars in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.21.0)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.0->ultralytics) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.6.15)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.5.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.0->ultralytics) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.23.0->ultralytics) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.23.0->ultralytics) (2024.2.0)
# Downloading ultralytics-8.3.204-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.4 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 86.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 67.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 23.6 MB/s eta 0:00:0000:0100:01m
# Downloading ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.204 ultralytics-thop-2.0.17

# %%
# Cell 1: Imports and setup directories
import pandas as pd
import cv2
import os
import shutil
from pathlib import Path

# Create dataset structure
os.makedirs('/kaggle/working/datasets/images/train', exist_ok=True)
os.makedirs('/kaggle/working/datasets/images/test', exist_ok=True)
os.makedirs('/kaggle/working/datasets/labels/train', exist_ok=True)
os.makedirs('/kaggle/working/datasets/labels/test', exist_ok=True)

print("Directories created.")
# Out:
# Directories created.

# %%
# Cell 2: Copy images to dataset structure (instead of symlinking)
train_input_dir = '/kaggle/input/qrcodes/QR_Dataset/train_images'
test_input_dir = '/kaggle/input/qrcodes/QR_Dataset/test_images'
train_output_dir = '/kaggle/working/datasets/images/train'
test_output_dir = '/kaggle/working/datasets/images/test'

# Copy train images
for i in range(1, 201):
    src = f'{train_input_dir}/img{i:03d}.jpg'
    dst = f'{train_output_dir}/img{i:03d}.jpg'
    if os.path.exists(src):
        shutil.copy2(src, dst)  # Copy file with metadata
    else:
        print(f"Warning: {src} not found.")

# Copy test images
for i in range(201, 251):
    src = f'{test_input_dir}/img{i:03d}.jpg'
    dst = f'{test_output_dir}/img{i:03d}.jpg'
    if os.path.exists(src):
        shutil.copy2(src, dst)
    else:
        print(f"Warning: {src} not found.")

print("Images copied.")
# Out:
# Images copied.

# %%
# Cell 3: Load CSV and generate YOLO-format labels
df = pd.read_csv('/kaggle/input/annoted/combined.csv')
df.columns = ['image_id', 'x_min', 'y_min', 'x_max', 'y_max']  # Verify CSV headers

grouped = df.groupby('image_id')

for img_id, group in grouped:
    img_num = int(img_id[3:-4])  # e.g., 'img001.jpg' -> 1
    if 1 <= img_num <= 200:
        label_dir = '/kaggle/working/datasets/labels/train'
        img_base_path = '/kaggle/working/datasets/images/train'
    elif 201 <= img_num <= 250:
        label_dir = '/kaggle/working/datasets/labels/test'
        img_base_path = '/kaggle/working/datasets/images/test'
    else:
        print(f"Skipping unknown image: {img_id}")
        continue
    
    img_path = os.path.join(img_base_path, img_id)
    if not os.path.exists(img_path):
        print(f"Image not found: {img_path}")
        continue
    
    img = cv2.imread(img_path)
    if img is None:
        print(f"Could not load image: {img_path}")
        continue
    
    h, w = img.shape[:2]
    label_filename = f"{img_id[:-4]}.txt"
    label_path = os.path.join(label_dir, label_filename)
    
    with open(label_path, 'w') as f:
        for _, row in group.iterrows():
            xmin = row['x_min']
            ymin = row['y_min']
            xmax = row['x_max']
            ymax = row['y_max']
            
            # Convert to YOLO format: class x_center y_center width height (normalized)
            x_center = ((xmin + xmax) / 2) / w
            y_center = ((ymin + ymax) / 2) / h
            bbox_width = (xmax - xmin) / w
            bbox_height = (ymax - ymin) / h
            
            f.write(f"0 {x_center:.6f} {y_center:.6f} {bbox_width:.6f} {bbox_height:.6f}\n")
    
    print(f"Generated labels for {img_id}")

print("Labels generated.")
# Generated labels for img221.jpg
# Generated labels for img222.jpg
# Generated labels for img223.jpg
# Generated labels for img224.jpg
# Generated labels for img225.jpg
# Generated labels for img226.jpg
# Generated labels for img227.jpg
# Generated labels for img228.jpg
# Generated labels for img229.jpg
# Generated labels for img230.jpg
# Generated labels for img231.jpg
# Generated labels for img232.jpg
# Generated labels for img233.jpg
# Generated labels for img234.jpg
# Generated labels for img235.jpg
# Generated labels for img236.jpg
# Generated labels for img237.jpg
# Generated labels for img238.jpg
# Generated labels for img239.jpg
# Generated labels for img240.jpg
# Generated labels for img241.jpg
# Generated labels for img242.jpg
# Generated labels for img243.jpg
# Generated labels for img244.jpg
# Generated labels for img245.jpg
# Generated labels for img246.jpg
# Generated labels for img247.jpg
# Generated labels for img248.jpg
# Generated labels for img249.jpg
# Generated labels for img250.jpg
# Labels generated.

# %%
# Cell 4: Create data.yaml configuration file
yaml_content = """
path: /kaggle/working/datasets
train: images/train
val: images/test
nc: 1
names: ['QR']
"""

with open('/kaggle/working/data1.yaml', 'w') as f:
    f.write(yaml_content)

print("data.yaml created. Contents:")
# !cat /kaggle/working/data1.yaml
# Out:
# data.yaml created. Contents:
#
# path: /kaggle/working/datasets
# train: images/train
# val: images/test
# nc: 1
# names: ['QR']

# %%
# Cell 5: Train the YOLOv12 model
from ultralytics import YOLO

# Load YOLOv12 small model
model = YOLO('yolo12s.pt')  # Changed to small model as per your output

# Train the model
results = model.train(
    data='/kaggle/working/data1.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    workers=0,     # Set to 0 to avoid issues with Kaggle's environment
    project='/kaggle/working/yolo_runs',
    name='qr_detection',
    patience=100,  # Prevent early stopping for small dataset
    exist_ok=True  # Allow overwriting runs
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo12s.pt to 'yolo12s.pt': 100% ━━━━━━━━━━━━ 18.1MB 118.0MB/s 0.2s1s<0.1s
# Ultralytics 8.3.204 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/data1.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=qr_detection, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolo_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo_runs/qr_detection, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.6MB/s 0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 4]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1    345856  ultralytics.nn.modules.block.A2C2f           [768, 256, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     95104  ultralytics.nn.modules.block.A2C2f           [512, 128, 1, False, -1]
#  15                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1    296704  ultralytics.nn.modules.block.A2C2f           [384, 256, 1, False, -1]
#  18                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  21        [14, 17, 20]  1    819795  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# YOLOv12s summary: 272 layers, 9,253,523 parameters, 9,253,507 gradients, 21.5 GFLOPs
#
# Transferred 685/691 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 70.8MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2365.4±1073.0 MB/s, size: 2564.0 KB)
# train: Scanning /kaggle/working/datasets/labels/train... 200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 200/200 15.3it/s 13.1s<0.0s
# train: /kaggle/working/datasets/images/train/img001.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img002.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img003.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img004.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img005.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img006.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img007.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img008.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img009.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img010.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img011.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img012.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img013.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img014.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img015.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img016.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img017.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img018.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img019.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img020.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img021.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img022.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img023.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img024.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img025.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img026.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img027.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img028.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img029.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img030.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img031.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img032.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img033.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img034.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img035.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img036.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img037.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img038.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img039.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img040.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img041.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img042.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img043.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img044.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img045.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img046.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img047.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img048.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img049.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img050.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img051.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img052.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img053.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img054.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img055.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img056.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img057.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img058.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img059.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img060.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img061.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img062.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img063.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img064.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img065.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img066.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img067.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img068.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img069.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img070.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img071.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img072.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img073.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img074.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img075.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img076.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img077.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img078.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img079.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img080.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img081.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img082.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img083.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img084.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img085.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img086.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img090.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img091.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img092.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img093.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img094.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img095.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img096.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img097.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img098.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img099.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img100.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img101.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img102.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img103.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img104.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img105.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img106.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img107.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img108.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img109.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img110.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img111.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img112.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img113.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img114.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img115.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img116.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img117.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img118.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img119.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img120.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img121.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img122.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img123.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img124.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img125.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img126.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img127.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img128.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img129.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img132.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img133.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img134.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img135.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img136.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img137.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img138.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img139.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img140.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img141.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img142.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img143.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img144.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img145.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img146.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img147.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img148.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img149.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img150.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img151.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img152.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img153.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img154.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img155.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img156.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img157.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img158.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img159.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img160.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img161.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img162.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img163.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img164.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img165.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img166.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img167.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img168.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img169.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img170.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img171.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img172.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img173.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img174.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img175.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img176.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img177.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img178.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img180.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img181.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img182.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img184.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img185.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img186.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img190.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img191.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img193.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img194.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img195.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img196.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img197.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img198.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img199.jpg: corrupt JPEG restored and saved
# train: /kaggle/working/datasets/images/train/img200.jpg: corrupt JPEG restored and saved
# train: New cache created: /kaggle/working/datasets/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3156.5±461.8 MB/s, size: 2378.1 KB)
# val: Scanning /kaggle/working/datasets/labels/test... 50 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 50/50 21.1it/s 2.4s0.1s
# val: /kaggle/working/datasets/images/test/img201.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img202.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img203.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img204.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img205.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img206.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img207.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img208.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img209.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img210.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img211.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img212.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img213.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img214.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img215.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img218.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img223.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img224.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img229.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img231.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img232.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img233.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img234.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img235.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img238.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img239.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img240.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img242.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img243.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img244.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img245.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img246.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img248.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img249.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img250.jpg: corrupt JPEG restored and saved
# val: New cache created: /kaggle/working/datasets/labels/test.cache
# Plotting labels to /kaggle/working/yolo_runs/qr_detection/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 113 weight(decay=0.0), 120 weight(decay=0.0005), 119 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /kaggle/working/yolo_runs/qr_detection
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      5.95G      2.736      4.519      1.845         64        640: 100% ━━━━━━━━━━━━ 13/13 0.5it/s 26.5s1.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.3it/s 6.4s13.7s
#                    all         50        180       0.82      0.894       0.91      0.432
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      6.75G      1.505      1.035      1.089         75        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 18.3s1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s11.0s
#                    all         50        180       0.03      0.933     0.0296     0.0161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      6.81G      1.388     0.8461      1.069         58        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 18.6s1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s11.0s
#                    all         50        180     0.0258      0.867     0.0249      0.013
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      6.83G      1.461      0.833      1.066         71        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 17.5s1.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.6s11.0s
#                    all         50        180    0.00696      0.472    0.00509    0.00248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      6.89G      1.461     0.7916      1.081         70        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 17.9s1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s10.9s
#                    all         50        180      0.026      0.867     0.0248     0.0119
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      6.93G       1.46     0.7978      1.071         78        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 18.8s1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s11.0s
#                    all         50        180          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      6.96G      1.446     0.7705      1.047         52        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 19.0s1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.6s11.3s
#                    all         50        180          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50         7G      1.484     0.7502      1.074         65        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 19.8s1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.6s11.4s
#                    all         50        180    0.00947      0.439    0.00652    0.00311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      7.03G      1.384     0.7435      1.045         54        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 18.8s1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.6s11.3s
#                    all         50        180      0.037      0.556     0.0307      0.016
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      7.08G      1.504     0.7757      1.082         55        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 19.0s1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.6s11.3s
#                    all         50        180      0.786      0.794      0.766      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50
0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      6.84G      1.151     0.4944     0.9514         84        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 20.0s1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s10.9s
#                    all         50        180      0.952      0.978      0.965      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      6.88G      1.096     0.4879       0.95         67        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 18.6s1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s10.8s
#                    all         50        180      0.968      0.994      0.992      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      6.92G      1.151     0.5047     0.9513         53        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 18.2s1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s10.9s
#                    all         50        180      0.956      0.972      0.967      0.551
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      6.94G      1.106     0.4724      0.977         30        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 17.8s1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s11.0s
#                    all         50        180      0.989      0.994      0.994      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50         7G      1.093      0.455     0.9753         44        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 17.4s1.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.4s10.9s
#                    all         50        180      0.989      0.993      0.994      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      7.04G       1.09      0.459     0.9803         24        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 19.6s1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s11.1s
#                    all         50        180      0.983      0.994      0.994        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      7.08G      1.082     0.4637     0.9746         21        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 18.4s1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s10.9s
#                    all         50        180       0.96      0.978      0.971      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50       7.1G      1.095     0.4694     0.9667         45        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 17.9s1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s11.0s
#                    all         50        180      0.962      0.983      0.979      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      7.15G      1.058     0.4542     0.9466         27        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 18.6s1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s11.1s
#                    all         50        180      0.958      0.983      0.974      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      7.19G       1.06     0.4517     0.9594         46        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 19.5s1.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s11.1s
#                    all         50        180      0.967      0.983      0.977      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      7.23G      1.063      0.437     0.9937         27        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 19.1s1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s10.9s
#                    all         50        180      0.974      0.989      0.984      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      7.29G      1.051     0.4361     0.9567         45        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 18.0s1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.5s11.1s
#                    all         50        180      0.983      0.989      0.988      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      7.34G      1.019     0.4219     0.9565         44        640: 100% ━━━━━━━━━━━━ 13/13 0.7it/s 18.1s1.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.4it/s 5.6s11.0s
#                    all         50        180      0.972      0.977       0.97      0.578
#
# 50 epochs completed in 0.345 hours.
# Optimizer stripped from /kaggle/working/yolo_runs/qr_detection/weights/last.pt, 18.9MB
# Optimizer stripped from /kaggle/working/yolo_runs/qr_detection/weights/best.pt, 18.9MB
#
# Validating /kaggle/working/yolo_runs/qr_detection/weights/best.pt...
# Ultralytics 8.3.204 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv12s summary (fused): 159 layers, 9,231,267 parameters, 0 gradients, 21.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 0.3it/s 5.8s11.2s
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all         50        180      0.989      0.994      0.994      0.607
# Speed: 0.2ms preprocess, 8.2ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /kaggle/working/yolo_runs/qr_detection

# %%
# Cell 6: Validate the trained model for testing accuracy
from ultralytics import YOLO
import numpy as np

# Load the trained model
model = YOLO('/kaggle/working/yolo_runs/qr_detection/weights/best.pt')

# Run validation on the test set
metrics = model.val(data='/kaggle/working/data1.yaml')

# Calculate F1 score
precision = metrics.box.mp
recall = metrics.box.mr
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

# Access confusion matrix to compute TP, FP, FN (and TN if applicable)
if hasattr(metrics, 'confusion_matrix'):
    cm = metrics.confusion_matrix.matrix  # Confusion matrix as numpy array
    # Assuming binary detection (e.g., QR code vs. background) or multi-class summed
    TP = np.diag(cm).sum()  # True Positives: sum of diagonal (correct predictions)
    FP = cm.sum(axis=0)[:-1].sum() - TP  # False Positives: predicted positive but wrong
    FN = cm.sum(axis=1)[:-1].sum() - TP  # False Negatives: missed positives
    TN = cm[-1, -1] if cm.shape[0] > 1 else 0  # True Negatives: background correctly not detected (if applicable)

    # Calculate accuracy: (TP + TN) / (TP + TN + FP + FN)
    total = TP + TN + FP + FN
    accuracy = (TP + TN) / total if total > 0 else 0
else:
    # Fallback: approximate accuracy using TP and FP (if TN not available)
    TP = metrics.box.tp.sum() if hasattr(metrics.box, 'tp') else 0
    FP = metrics.box.fp.sum() if hasattr(metrics.box, 'fp') else 0
    FN = metrics.box.fn.sum() if hasattr(metrics.box, 'fn') else 0
    TN = 0  # TN often not used in object detection
    total = TP + TN + FP + FN
    accuracy = (TP + TN) / total if total > 0 else 0

# Print metrics
print(f"mAP50-95: {metrics.box.map:.4f}")
print(f"mAP50: {metrics.box.map50:.4f}")
print(f"mAP75: {metrics.box.map75:.4f}")
print(f"Precision: {metrics.box.mp:.4f}")
print(f"Recall: {metrics.box.mr:.4f}")
print(f"F1 Score: {f1_score:.4f}")
print(f"Accuracy (TP + TN) / (TP + TN + FP + FN): {accuracy:.4f}")
print(f"Per-class mAP50-95: {metrics.box.maps}")
# Out:
# Ultralytics 8.3.204 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv12s summary (fused): 159 layers, 9,231,267 parameters, 0 gradients, 21.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4720.3±885.8 MB/s, size: 3501.9 KB)
# val: Scanning /kaggle/working/datasets/labels/test.cache... 50 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 50/50 86.2Kit/s 0.0s
# val: /kaggle/working/datasets/images/test/img201.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img202.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img203.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img204.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img205.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img206.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img207.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img208.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img209.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img210.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img211.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img212.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img213.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img214.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img215.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img218.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img223.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img224.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img229.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img231.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img232.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img233.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img234.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img235.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img238.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img239.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img240.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img242.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img243.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img244.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img245.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img246.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img248.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img249.jpg: corrupt JPEG restored and saved
# val: /kaggle/working/datasets/images/test/img250.jpg: corrupt JPEG restored and saved
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.9it/s 4.2s1.5ss
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
#                    all         50        180      0.989      0.994      0.994      0.607
# Speed: 2.7ms preprocess, 16.6ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val
# mAP50-95: 0.6074
# mAP50: 0.9942
# mAP75: 0.6590
# Precision: 0.9889
# Recall: 0.9942
# F1 Score: 0.9916
# Accuracy (TP + TN) / (TP + TN + FP + FN): 0.9624
# Per-class mAP50-95: [    0.60743]

# %%
import os
import pandas as pd
from ultralytics import YOLO

# Load the trained model
model = YOLO('/kaggle/working/yolo_runs/qr_detection/weights/best.pt')

# Load the annotations CSV
df = pd.read_csv('/kaggle/input/annoted/combined.csv')
df.columns = ['image_id', 'x_min', 'y_min', 'x_max', 'y_max']

# Filter for test images (img201.jpg to img250.jpg)
test_image_ids = [f'img{i:03d}.jpg' for i in range(201, 251)]
df_test = df[df['image_id'].isin(test_image_ids)]

# Count ground truth QR codes per test image
ground_truth_counts = df_test.groupby('image_id').size().reset_index(name='ground_truth_qr_codes')

# Predict QR codes on test images
test_images_dir = '/kaggle/working/datasets/images/test'
results = model.predict(
    source=test_images_dir,
    save=True,
    conf=0.25,
    iou=0.45,
    project='/kaggle/working/yolo_runs',
    name='qr_detection_predict'
)

# Count predicted QR codes per image
predicted_counts = []
for result in results:
    img_path = result.path
    img_id = os.path.basename(img_path)
    if img_id in test_image_ids:  # Only include test images
        num_detections = len(result.boxes)
        predicted_counts.append({'image_id': img_id, 'predicted_qr_codes': num_detections})

predicted_df = pd.DataFrame(predicted_counts)

# Merge ground truth and predicted counts
report_df = ground_truth_counts.merge(predicted_df, on='image_id', how='left')
report_df['predicted_qr_codes'] = report_df['predicted_qr_codes'].fillna(0).astype(int)

# Calculate sums for test set
total_ground_truth = report_df['ground_truth_qr_codes'].sum()
total_predicted = report_df['predicted_qr_codes'].sum()

# Print sums only
print("\nQR Code Detection Report (Test Set, img201.jpg to img250.jpg):")
print(f"Total Ground Truth QR Codes: {total_ground_truth}")
print(f"Total Predicted QR Codes: {total_predicted}")

# Save report to a CSV file
report_df.to_csv('/kaggle/working/yolo_runs/qr_detection_predict/qr_code_report.csv', index=False)
print("\nReport saved to /kaggle/working/yolo_runs/qr_detection_predict/qr_code_report.csv")
# Out:
# image 1/50 /kaggle/working/datasets/images/test/img201.jpg: 640x384 1 QR, 56.1ms
# image 2/50 /kaggle/working/datasets/images/test/img202.jpg: 384x640 1 QR, 55.0ms
# image 3/50 /kaggle/working/datasets/images/test/img203.jpg: 640x384 6 QRs, 15.9ms
# image 4/50 /kaggle/working/datasets/images/test/img204.jpg: 640x384 5 QRs, 14.7ms
# image 5/50 /kaggle/working/datasets/images/test/img205.jpg: 640x384 5 QRs, 14.6ms
# image 6/50 /kaggle/working/datasets/images/test/img206.jpg: 640x384 4 QRs, 15.7ms
# image 7/50 /kaggle/working/datasets/images/test/img207.jpg: 640x384 6 QRs, 15.0ms
# image 8/50 /kaggle/working/datasets/images/test/img208.jpg: 640x384 4 QRs, 14.8ms
# image 9/50 /kaggle/working/datasets/images/test/img209.jpg: 640x384 6 QRs, 16.5ms
# image 10/50 /kaggle/working/datasets/images/test/img210.jpg: 640x384 7 QRs, 14.9ms
# image 11/50 /kaggle/working/datasets/images/test/img211.jpg: 640x384 1 QR, 15.4ms
# image 12/50 /kaggle/working/datasets/images/test/img212.jpg: 640x384 1 QR, 15.3ms
# image 13/50 /kaggle/working/datasets/images/test/img213.jpg: 640x384 1 QR, 14.9ms
# image 14/50 /kaggle/working/datasets/images/test/img214.jpg: 640x384 5 QRs, 14.9ms
# image 15/50 /kaggle/working/datasets/images/test/img215.jpg: 640x384 4 QRs, 14.9ms
# image 16/50 /kaggle/working/datasets/images/test/img216.jpg: 480x640 1 QR, 55.1ms
# image 17/50 /kaggle/working/datasets/images/test/img217.jpg: 640x480 4 QRs, 54.5ms
# image 18/50 /kaggle/working/datasets/images/test/img218.jpg: 640x384 7 QRs, 16.5ms
# image 19/50 /kaggle/working/datasets/images/test/img219.jpg: 480x640 5 QRs, 16.4ms
# image 20/50 /kaggle/working/datasets/images/test/img220.jpg: 480x640 6 QRs, 15.7ms
# image 21/50 /kaggle/working/datasets/images/test/img221.jpg: 480x640 4 QRs, 15.7ms
# image 22/50 /kaggle/working/datasets/images/test/img222.jpg: 480x640 4 QRs, 15.7ms
# image 23/50 /kaggle/working/datasets/images/test/img223.jpg: 640x384 3 QRs, 16.4ms
# image 24/50 /kaggle/working/datasets/images/test/img224.jpg: 640x384 1 QR, 15.1ms
# image 25/50 /kaggle/working/datasets/images/test/img225.jpg: 512x640 4 QRs, 55.8ms
# image 26/50 /kaggle/working/datasets/images/test/img226.jpg: 512x640 4 QRs, 16.2ms
# image 27/50 /kaggle/working/datasets/images/test/img227.jpg: 512x640 4 QRs, 16.1ms
# image 28/50 /kaggle/working/datasets/images/test/img228.jpg: 512x640 4 QRs, 16.2ms
# image 29/50 /kaggle/working/datasets/images/test/img229.jpg: 384x640 4 QRs, 15.6ms
# image 30/50 /kaggle/working/datasets/images/test/img230.jpg: 640x512 6 QRs, 55.1ms
# image 31/50 /kaggle/working/datasets/images/test/img231.jpg: 640x384 5 QRs, 15.6ms
# image 32/50 /kaggle/working/datasets/images/test/img232.jpg: 640x384 4 QRs, 15.2ms
# image 33/50 /kaggle/working/datasets/images/test/img233.jpg: 384x640 3 QRs, 15.5ms
# image 34/50 /kaggle/working/datasets/images/test/img234.jpg: 384x640 4 QRs, 14.8ms
# image 35/50 /kaggle/working/datasets/images/test/img235.jpg: 640x384 3 QRs, 16.0ms
# image 36/50 /kaggle/working/datasets/images/test/img236.jpg: 512x640 4 QRs, 16.8ms
# image 37/50 /kaggle/working/datasets/images/test/img237.jpg: 512x640 5 QRs, 16.1ms
# image 38/50 /kaggle/working/datasets/images/test/img238.jpg: 576x640 1 QR, 62.5ms
# image 39/50 /kaggle/working/datasets/images/test/img239.jpg: 640x352 2 QRs, 54.9ms
# image 40/50 /kaggle/working/datasets/images/test/img240.jpg: 640x384 3 QRs, 15.8ms
# image 41/50 /kaggle/working/datasets/images/test/img241.jpg: 512x640 5 QRs, 16.8ms
# image 42/50 /kaggle/working/datasets/images/test/img242.jpg: 640x384 2 QRs, 15.5ms
# image 43/50 /kaggle/working/datasets/images/test/img243.jpg: 352x640 2 QRs, 56.2ms
# image 44/50 /kaggle/working/datasets/images/test/img244.jpg: 384x640 3 QRs, 18.1ms
# image 45/50 /kaggle/working/datasets/images/test/img245.jpg: 384x640 5 QRs, 14.7ms
# image 46/50 /kaggle/working/datasets/images/test/img246.jpg: 640x384 3 QRs, 15.4ms
# image 47/50 /kaggle/working/datasets/images/test/img247.jpg: 512x640 4 QRs, 16.9ms
# image 48/50 /kaggle/working/datasets/images/test/img248.jpg: 384x640 3 QRs, 15.3ms
# image 49/50 /kaggle/working/datasets/images/test/img249.jpg: 384x640 4 QRs, 14.9ms
# image 50/50 /kaggle/working/datasets/images/test/img250.jpg: 384x640 4 QRs, 14.7ms
# Speed: 2.4ms preprocess, 22.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /kaggle/working/yolo_runs/qr_detection_predict
#
# QR Code Detection Report (Test Set, img201.jpg to img250.jpg):
# Total Ground Truth QR Codes: 180
# Total Predicted QR Codes: 187
#
# Report saved to /kaggle/working/yolo_runs/qr_detection_predict/qr_code_report.csv

# %%
import shutil
import os

# Define the folder or file to zip (adjust paths if needed)
folder_to_zip = '/kaggle/working/'  

# Create a zip file of the folder
zip_filename = 'modeltrain.zip'  
shutil.make_archive(zip_filename, 'zip', folder_to_zip)

print(f"Zip file created: /kaggle/working/{zip_filename}")
print("Now go to the Output tab in the right sidebar, find the zip file, and download it using the three dots menu.")
